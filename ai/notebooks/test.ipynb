# %%
#client.delete_collection()
import chromadb

chroma_client = chromadb.HttpClient(host='localhost', port=8000)

# %%
chroma_client.list_collections()
# Out:
# [Collection(name=kantuta_legal)]

# %%
chroma_client.delete_collection(name="kantuta_legal")

# %%
colection = chroma_client.get_collection(name="kantuta_legal")
